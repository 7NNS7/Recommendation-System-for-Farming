# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../Datasets/apy.csv')

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area Production
# 0             Arecanut  1254.0       2000
# 1  Other Kharif pulses     2.0          1
# 2                 Rice   102.0        321
# 3               Banana   176.0        641
# 4            Cashewnut   720.0        165

# %%
df.tail()
# Out:
#          State_Name District_Name  Crop_Year       Season       Crop  \
# 246086  West Bengal       PURULIA       2014  Summer            Rice
# 246087  West Bengal       PURULIA       2014  Summer         Sesamum
# 246088  West Bengal       PURULIA       2014  Whole Year   Sugarcane
# 246089  West Bengal       PURULIA       2014  Winter            Rice
# 246090  West Bengal       PURULIA       2014  Winter         Sesamum
#
#             Area Production
# 246086     306.0        801
# 246087     627.0        463
# 246088     324.0      16250
# 246089  279151.0     597899
# 246090     175.0         88

# %%
df.State_Name.unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df.Crop_Year.unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2010, 1997, 1998, 1999,
#        2007, 2008, 2009, 2011, 2012, 2013, 2014, 2015])

# %%
karnataka = df[df['State_Name'] == "Karnataka"]

# %%
karnataka.head()
# Out:
#       State_Name District_Name  Crop_Year       Season          Crop     Area  \
# 76865  Karnataka      BAGALKOT       1998  Kharif          Arhar/Tur   6154.0
# 76866  Karnataka      BAGALKOT       1998  Kharif              Bajra  48855.0
# 76867  Karnataka      BAGALKOT       1998  Kharif        Castor seed     71.0
# 76868  Karnataka      BAGALKOT       1998  Kharif       Cotton(lint)  15225.0
# 76869  Karnataka      BAGALKOT       1998  Kharif          Groundnut  16368.0
#
#       Production
# 76865       2602
# 76866      52375
# 76867         61
# 76868      22129
# 76869       7734

# %%
karnataka = karnataka[['District_Name','Crop_Year','Season','Crop']]

# %%
karnataka.head()
# Out:
#       District_Name  Crop_Year       Season          Crop
# 76865      BAGALKOT       1998  Kharif          Arhar/Tur
# 76866      BAGALKOT       1998  Kharif              Bajra
# 76867      BAGALKOT       1998  Kharif        Castor seed
# 76868      BAGALKOT       1998  Kharif       Cotton(lint)
# 76869      BAGALKOT       1998  Kharif          Groundnut

# %%
karnataka.District_Name.unique()
# Out:
# array(['BAGALKOT', 'BANGALORE RURAL', 'BELGAUM', 'BELLARY',
#        'BENGALURU URBAN', 'BIDAR', 'BIJAPUR', 'CHAMARAJANAGAR',
#        'CHIKBALLAPUR', 'CHIKMAGALUR', 'CHITRADURGA', 'DAKSHIN KANNAD',
#        'DAVANGERE', 'DHARWAD', 'GADAG', 'GULBARGA', 'HASSAN', 'HAVERI',
#        'KODAGU', 'KOLAR', 'KOPPAL', 'MANDYA', 'MYSORE', 'RAICHUR',
#        'RAMANAGARA', 'SHIMOGA', 'TUMKUR', 'UDUPI', 'UTTAR KANNAD',
#        'YADGIR'], dtype=object)

# %%
karnataka.Season.unique()
# Out:
# array(['Kharif     ', 'Rabi       ', 'Summer     ', 'Whole Year '],
#       dtype=object)

# %%
karnataka.Crop.unique()
# Out:
# array(['Arhar/Tur', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Groundnut',
#        'Horse-gram', 'Jowar', 'Maize', 'Moong(Green Gram)', 'Niger seed',
#        'Onion', 'Rapeseed &Mustard', 'Rice', 'Sesamum', 'Soyabean',
#        'Sunflower', 'Gram', 'Linseed', 'Safflower', 'Wheat', 'Arecanut',
#        'Coconut ', 'Coriander', 'Dry chillies', 'Garlic', 'Turmeric',
#        'Mesta', 'Other Kharif pulses', 'Small millets',
#        'Other  Rabi pulses', 'Banana', 'Sugarcane', 'Sweet potato',
#        'Sannhamp', 'Arcanut (Processed)', 'Atcanut (Raw)', 'Brinjal',
#        'Citrus Fruit', 'Grapes', 'Mango', 'Other Fresh Fruits', 'Papaya',
#        'Pome Fruit', 'Tomato', 'Urad', 'Cashewnut', 'Tobacco',
#        'Cowpea(Lobia)', 'Black pepper', 'Dry ginger', 'Paddy',
#        'Peas & beans (Pulses)', 'Potato', 'Ragi', 'Tapioca',
#        'Beans & Mutter(Vegetable)', 'Cashewnut Processed',
#        'Cashewnut Raw', 'Cardamom'], dtype=object)

# %%
karnataka.Crop_Year.unique()
# Out:
# array([1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 1997])

# %%
karnataka_2014 = karnataka[karnataka['Crop_Year'] == 2014]

# %%
del karnataka_2014['Crop_Year']

# %%
karnataka_2014
# Out:
#       District_Name       Season           Crop
# 77555      BAGALKOT  Kharif           Arhar/Tur
# 77556      BAGALKOT  Kharif               Bajra
# 77557      BAGALKOT  Kharif        Cotton(lint)
# 77558      BAGALKOT  Kharif       Cowpea(Lobia)
# 77559      BAGALKOT  Kharif        Dry chillies
# ...             ...          ...            ...
# 97982        YADGIR  Summer                Rice
# 97983        YADGIR  Summer           Sunflower
# 97984        YADGIR  Whole Year        Coconut
# 97985        YADGIR  Whole Year       Coriander
# 97986        YADGIR  Whole Year       Sugarcane
#
# [1312 rows x 3 columns]

# %%
sns.countplot(karnataka_2014['Season'])

# %%
plt.figure(figsize=[12,7],dpi = 450)
plt.xticks(rotation = 90,ha = "right")
sns.countplot(karnataka_2014['Crop'])

# %%
karnataka_2014.groupby(['District_Name','Season']).sum()
# Out:
#                                                                           Crop
# District_Name   Season
# BAGALKOT        Kharif       Arhar/TurBajraCotton(lint)Cowpea(Lobia)Dry chi...
#                 Rabi         Cotton(lint)Cowpea(Lobia)Dry chilliesGramHorse...
#                 Summer       Cotton(lint)Cowpea(Lobia)Dry chilliesGroundnut...
#                 Whole Year        Coconut CorianderDry gingerSugarcaneTurmeric
# BANGALORE RURAL Kharif       Arhar/TurCastor seedCowpea(Lobia)Dry chilliesG...
# ...                                                                        ...
# UTTAR KANNAD    Whole Year   ArecanutBlack pepperCardamomCashewnutCoconut D...
# YADGIR          Kharif       Arhar/TurBajraCastor seedCotton(lint)Cowpea(Lo...
#                 Rabi         Cowpea(Lobia)Dry chilliesGramHorse-gramJowarMa...
#                 Summer       Cowpea(Lobia)GroundnutJowarMaizeOnionRiceSunfl...
#                 Whole Year                          Coconut CorianderSugarcane
#
# ...

# %%
cp = pd.read_csv('../Datasets/cpdata.csv')

# %%
cp.head()
# Out:
#    temperature   humidity        ph    rainfall label
# 0    20.879744  82.002744  6.502985  202.935536  rice
# 1    21.770462  80.319644  7.038096  226.655537  rice
# 2    23.004459  82.320763  7.840207  263.964248  rice
# 3    26.491096  80.158363  6.980401  242.864034  rice
# 4    20.130175  81.604873  7.628473  262.717340  rice

# %%
cp.label.unique()
# Out:
# array(['rice', 'wheat', 'Mung Bean', 'Tea', 'millet', 'maize', 'Lentil',
#        'Jute', 'Coffee', 'Cotton', 'Ground Nut', 'Peas', 'Rubber',
#        'Sugarcane', 'Tobacco', 'Kidney Beans', 'Moth Beans', 'Coconut',
#        'Black gram', 'Adzuki Beans', 'Pigeon Peas', 'Chickpea', 'banana',
#        'grapes', 'apple', 'mango', 'muskmelon', 'orange', 'papaya',
#        'pomegranate', 'watermelon'], dtype=object)

# %%
cp.size
# Out:
# 15500

# %%
cp
# Out:
#       temperature   humidity        ph    rainfall       label
# 0       20.879744  82.002744  6.502985  202.935536        rice
# 1       21.770462  80.319644  7.038096  226.655537        rice
# 2       23.004459  82.320763  7.840207  263.964248        rice
# 3       26.491096  80.158363  6.980401  242.864034        rice
# 4       20.130175  81.604873  7.628473  262.717340        rice
# ...           ...        ...       ...         ...         ...
# 3095    25.287846  89.636679  6.765095   58.286977  watermelon
# 3096    26.638386  84.695469  6.189214   48.324286  watermelon
# 3097    25.331045  84.305338  6.904242   41.532187  watermelon
# 3098    26.897502  83.892415  6.463271   43.971937  watermelon
# 3099    26.986037  89.413849  6.260839   58.548767  watermelon
#
# [3100 rows x 5 columns]

# %%
ls
# Out:
# 'Crop Recommendation.ipynb'   ForModel.csv
# 'EDA for Dataset 1.ipynb'*   'Logistic Regression.ipynb'
# 'EDA of Dataset 2.ipynb'*    'Overview of datasets.ipynb'

# %%
df
