# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Datasets/FinalData.csv')

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  73  57  44    20.879744  82.002744  6.502985  202.935536  rice
# 1  74  57  44    21.770462  80.319644  7.038096  226.655537  rice
# 2  92  41  38    23.004459  82.320763  7.840207  263.964248  rice
# 3  68  44  38    26.491096  80.158363  6.980401  242.864034  rice
# 4  66  36  40    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195   88  27  30    26.774637  66.413269  6.780064  177.774507  coffee
# 2196  119  37  30    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  103  38  29    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  106  22  31    26.272418  52.127394  6.758793  127.175293  coffee
# 2199   86  20  28    23.603016  60.396475  6.779833  140.937041  coffee

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
len(df['label'].unique())
# Out:
# 22

# %%
plt.figure(dpi = 250)
sns.heatmap(df.corr(),annot = True)

# %%
plt.figure(dpi = 250)
plt.plot(df['temperature'])

# %%
plt.figure(dpi = 250)
plt.plot(df['ph'])

# %%
plt.figure(dpi = 250)
plt.plot(df['rainfall'])

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     49.992727    53.300000    48.169545    25.616244    71.481779
# std      37.195854    32.676122    50.672493     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      20.000000    28.000000    21.000000    22.769375    60.261953
# 50%      37.000000    51.000000    31.000000    25.598693    80.473146
# 75%      85.000000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df["N"]
# Out:
# 0        73
# 1        74
# 2        92
# 3        68
# 4        66
#        ...
# 2195     88
# 2196    119
# 2197    103
# 2198    106
# 2199     86
# Name: N, Length: 2200, dtype: int64

# %%
df[df['label'] == "chickpea"]
# Out:
#       N   P   K  temperature   humidity        ph   rainfall     label
# 200  28  60  82    17.024985  16.988612  7.485996  88.551231  chickpea
# 201  22  65  85    19.020613  17.131591  6.920251  79.926981  chickpea
# 202  24  65  85    17.887765  15.405897  5.996932  68.549329  chickpea
# 203  58  75  81    18.868056  15.658092  6.391174  88.510490  chickpea
# 204  33  55  81    18.369526  19.563810  7.152811  79.263577  chickpea
# ..   ..  ..  ..          ...        ...       ...        ...       ...
# 295  37  75  83    17.341502  18.756263  8.861480  67.954543  chickpea
# 296  25  70  85    17.437327  14.338474  7.861128  73.092670  chickpea
# 297  60  67  78    18.897802  19.761829  7.452671  69.095125  chickpea
# 298  53  75  75    18.591908  14.779596  7.168096  89.609825  chickpea
# 299  50  67  76    18.315615  15.361435  7.263119  81.787105  chickpea
#
# [100 rows x 8 columns]
