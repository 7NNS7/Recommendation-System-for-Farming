# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Datasets/FinalData.csv')

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  81  41  40    20.879744  82.002744  6.502985  202.935536  rice
# 1  81  37  40    21.770462  80.319644  7.038096  226.655537  rice
# 2  81  40  37    23.004459  82.320763  7.840207  263.964248  rice
# 3  82  42  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  77  39  37    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  103  20  29    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  17  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197   98  22  29    24.131797  67.225123  6.362608  173.322839  coffee
# 2198   98  21  28    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  103  17  28    23.603016  60.396475  6.779833  140.937041  coffee

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
len(df['label'].unique())
# Out:
# 22

# %%
plt.figure(dpi = 250)
sns.heatmap(df.corr(),annot = True)

# %%
plt.figure(dpi = 250)
plt.plot(df['temperature'])

# %%
plt.figure(dpi = 250)
plt.plot(df['ph'])

# %%
plt.figure(dpi = 250)
plt.plot(df['rainfall'])

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.435455    45.630909    48.171364    25.616244    71.481779
# std      35.499008    31.980356    50.637888     5.063749    22.263812
# min      17.000000     7.000000     7.000000     8.825675    14.258040
# 25%      20.000000    18.000000    20.000000    22.769375    60.261953
# 50%      30.000000    41.000000    31.000000    25.598693    80.473146
# 75%      82.000000    60.000000    49.000000    28.561654    89.948771
# max     123.000000   128.000000   203.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df["N"]
# Out:
# 0        81
# 1        81
# 2        81
# 3        82
# 4        77
#        ...
# 2195    103
# 2196     99
# 2197     98
# 2198     98
# 2199    103
# Name: N, Length: 2200, dtype: int64

# %%
df[df['label'] == "chickpea"]
# Out:
#       N   P   K  temperature   humidity        ph   rainfall     label
# 200  40  63  81    17.024985  16.988612  7.485996  88.551231  chickpea
# 201  39  60  80    19.020613  17.131591  6.920251  79.926981  chickpea
# 202  40  63  77    17.887765  15.405897  5.996932  68.549329  chickpea
# 203  41  62  82    18.868056  15.658092  6.391174  88.510490  chickpea
# 204  41  58  83    18.369526  19.563810  7.152811  79.263577  chickpea
# ..   ..  ..  ..          ...        ...       ...        ...       ...
# 295  41  59  79    17.341502  18.756263  8.861480  67.954543  chickpea
# 296  38  58  82    17.437327  14.338474  7.861128  73.092670  chickpea
# 297  41  62  83    18.897802  19.761829  7.452671  69.095125  chickpea
# 298  41  60  77    18.591908  14.779596  7.168096  89.609825  chickpea
# 299  37  57  79    18.315615  15.361435  7.263119  81.787105  chickpea
#
# [100 rows x 8 columns]
